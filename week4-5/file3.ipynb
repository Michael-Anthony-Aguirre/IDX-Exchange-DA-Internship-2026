# %%
import pandas as pd

# %%
df_sold = pd.read_csv("CRMLSSold_3.csv", low_memory = False)
df_listings = pd.read_csv("CRMLSListing_3.csv", low_memory = False)

# %%
df_sold.head()
# Out:
#         BuyerAgentAOR        ListAgentAOR   Flooring ViewYN PoolPrivateYN  \
# 0         ContraCosta         ContraCosta  Tile,Wood    NaN         False
# 1                 NaN         Mlslistings        NaN  False           NaN
# 2            Glendale           Southland        NaN  False         False
# 3  NorthSanLuisObispo  NorthSanLuisObispo        NaN   True         False
# 4    CoastalMendocino    CoastalMendocino       Tile   True         False
#
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0          5000000.0  1095075487  2024-01-18   5000000.0               Erin
# 1                NaN  1079166779  2024-01-30    858000.0              David
# 2          1890500.0  1075037759  2024-01-29   1890500.0              Karen
# 3          2100000.0  1067652762  2024-01-02   2100000.0           Jennifer
# 4          1950000.0  1063453216  2024-01-22   1950000.0               Kira
#
# ...

# %%
df_listings.head()
# Out:
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0           759000.0  1159972295         NaN         NaN            Richard
# 1           320000.0  1159871345  2026-05-11    320000.0           Nicholas
# 2           115900.0  1153320466  2026-04-10    160000.0              Heidi
# 3          2500000.0  1146529264  2026-04-17   2000000.0           Clifford
# 4          3200000.0  1118382573  2025-05-21   3200000.0              Trudy
#
#   ListAgentLastName   Latitude   Longitude              UnparsedAddress  \
# 0            Sirois  33.738910 -116.198447        42680 Incantata Place
# 1            Miller  33.842793 -116.481803  28388 Desert Princess Drive
# 2      Dunk-Vincent  39.125903 -122.861472                   6900 Glenn
# 3           Stevens  34.150964 -118.390267             4415 Morella Ave
# 4           McGrath  33.028788 -117.264434           1200 Cardiff Drive
#
# ...

# %%
# Document every transformation you made & why.

# %%
# Row Counts (BEFORE)
print("Row Counts (BEFORE):")
print(f"- Sold: {len(df_sold)}")
print(f"- Listings: {len(df_listings)}")
# Out:
# Row Counts (BEFORE):
# - Sold: 455658
# - Listings: 504466

# %%
# Data Type Confirmations (BEFORE)
sold_dtypes = sorted(df_sold.dtypes.unique().astype(str).tolist())
listings_dtypes = sorted(df_listings.dtypes.unique().astype(str).tolist())

print("Data Type Confirmations (BEFORE):")
print(f"- Sold: {sold_dtypes}")
print(f"- Listings: {listings_dtypes}")
# Out:
# Data Type Confirmations (BEFORE):
# - Sold: ['float64', 'int64', 'object']
# - Listings: ['float64', 'int64', 'object']

# %%
# Convert date fields to datetime format: CloseDate, PurchaseContractDate, ListingContractDate, ContractStatusChangeDate
date_fields = ["CloseDate", "PurchaseContractDate", "ListingContractDate", "ContractStatusChangeDate"]

for field in date_fields:
    df_sold[field] = pd.to_datetime(df_sold[field])
    df_listings[field] = pd.to_datetime(df_listings[field])

# %%
# Remove unnecessary or redundant columns

# %%
# Handle missing values appropritately

# %%
# Ensure numeric fields are properly typed

# %%
# Remove or flag invalid numeric values:
## ClosePrice <= 0
## LivingArea <= 0
## DaysOnMarket < 0
## negative Bedrooms or Bathrooms

# %%
# Validate the logical order of date fields:
## - ListingContractDate should precede PurchaseContractDate
## - PurchaseContractDate should precede CloseDate
# Create boolean flag columns to mark records that violate these rules:
## - listing_after_close_flag
## - purchase_after_close_flag
## - negative_timeline_flag

# %%
# Flag records with missing coordinates (Latitude or Longitude is null)
# Flag Latitude = 0 or Longitude = 0 (sentinel null values)
# Flag Longitude > 0 errors (California coordinates should be negative)
# Flag out-of-state or implausible coordinates

# %%
# Row Counts (AFTER)
print("Row Counts (AFTER):")
print(f"- Sold: {len(df_sold)}")
print(f"- Listings: {len(df_listings)}")
# Out:
# Row Counts (AFTER):
# - Sold: 455658
# - Listings: 504466

# %%
# Data Type Confirmations (AFTER)
sold_dtypes = sorted(df_sold.dtypes.unique().astype(str).tolist())
listings_dtypes = sorted(df_listings.dtypes.unique().astype(str).tolist())

print("Data Type Confirmations (AFTER):")
print(f"- Sold: {sold_dtypes}")
print(f"- Listings: {listings_dtypes}")
# Out:
# Data Type Confirmations (AFTER):
# - Sold: ['datetime64[ns]', 'float64', 'int64', 'object']
# - Listings: ['datetime64[ns]', 'float64', 'int64', 'object']

# %%
# df_sold.to_csv("CRMLSSold_4.csv", index = False)
# df_listings.to_csv("CRMLSListing_4.csv", index = False)
